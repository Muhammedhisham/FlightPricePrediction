# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
# print(sklearn.__version__)

# %%
pip install --upgrade scikit-learn==1.4.1.post1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import sklearn
# print(sklearn.__version__)

# %%
data=pd.read_csv('Clean_Dataset.csv')

# %%
data['stops'].unique()
# Out:
# array(['zero', 'one', 'two_or_more'], dtype=object)

# %%
data
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
data['class'].unique()
# Out:
# array(['Economy', 'Business'], dtype=object)

# %%
data.isna().sum()
# Out:
# Unnamed: 0          0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
data['airline'].unique()
# Out:
# array(['SpiceJet', 'AirAsia', 'Vistara', 'GO_FIRST', 'Indigo',
#        'Air_India'], dtype=object)

# %%
data.drop(['flight', 'Unnamed: 0','duration','days_left'], axis=1,inplace=True)

# %%
data
# Out:
#          airline source_city departure_time stops   arrival_time  \
# 0       SpiceJet       Delhi        Evening  zero          Night
# 1       SpiceJet       Delhi  Early_Morning  zero        Morning
# 2        AirAsia       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara       Delhi        Morning  zero      Afternoon
# 4        Vistara       Delhi        Morning  zero        Morning
# ...          ...         ...            ...   ...            ...
# 300148   Vistara     Chennai        Morning   one        Evening
# 300149   Vistara     Chennai      Afternoon   one          Night
# 300150   Vistara     Chennai  Early_Morning   one          Night
# 300151   Vistara     Chennai  Early_Morning   one        Evening
# 300152   Vistara     Chennai        Morning   one        Evening
#
#        destination_city     class  price
# 0                Mumbai   Economy   5953
# 1                Mumbai   Economy   5953
# 2                Mumbai   Economy   5956
# ...

# %%
data['source_city'].unique()
# Out:
# array(['Delhi', 'Mumbai', 'Bangalore', 'Kolkata', 'Hyderabad', 'Chennai'],
#       dtype=object)

# %%
data['arrival_time'].unique()
# Out:
# array(['Night', 'Morning', 'Early_Morning', 'Afternoon', 'Evening',
#        'Late_Night'], dtype=object)

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()

# %%
data
# Out:
#          airline source_city departure_time stops   arrival_time  \
# 0       SpiceJet       Delhi        Evening  zero          Night
# 1       SpiceJet       Delhi  Early_Morning  zero        Morning
# 2        AirAsia       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara       Delhi        Morning  zero      Afternoon
# 4        Vistara       Delhi        Morning  zero        Morning
# ...          ...         ...            ...   ...            ...
# 300148   Vistara     Chennai        Morning   one        Evening
# 300149   Vistara     Chennai      Afternoon   one          Night
# 300150   Vistara     Chennai  Early_Morning   one          Night
# 300151   Vistara     Chennai  Early_Morning   one        Evening
# 300152   Vistara     Chennai        Morning   one        Evening
#
#        destination_city     class  price
# 0                Mumbai   Economy   5953
# 1                Mumbai   Economy   5953
# 2                Mumbai   Economy   5956
# ...

# %%
data['airline']=label_encoder.fit_transform(data['airline'])
data['source_city']=label_encoder.fit_transform(data['source_city'])
data['departure_time']=label_encoder.fit_transform(data['departure_time'])
data['stops']=label_encoder.fit_transform(data['stops'])
data['arrival_time']=label_encoder.fit_transform(data['arrival_time'])
data['destination_city']=label_encoder.fit_transform(data['destination_city'])
data['class']=label_encoder.fit_transform(data['class'])

# %%
data
# Out:
#         airline  source_city  departure_time  stops  arrival_time  \
# 0             4            2               2      2             5
# 1             4            2               1      2             4
# 2             0            2               1      2             1
# 3             5            2               4      2             0
# 4             5            2               4      2             4
# ...         ...          ...             ...    ...           ...
# 300148        5            1               4      0             2
# 300149        5            1               0      0             5
# 300150        5            1               1      0             5
# 300151        5            1               1      0             2
# 300152        5            1               4      0             2
#
#         destination_city  class  price
# 0                      5      1   5953
# 1                      5      1   5953
# 2                      5      1   5956
# ...

# %%
y=data['price']
x=data.drop(['price'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
len(x_train),len(x_test),len(y_train),len(y_test)
# Out:
# (210107, 90046, 210107, 90046)

# %%
from sklearn.ensemble import RandomForestRegressor
RF=RandomForestRegressor()

# %%
data
# Out:
#         airline  source_city  departure_time  stops  arrival_time  \
# 0             4            2               2      2             5
# 1             4            2               1      2             4
# 2             0            2               1      2             1
# 3             5            2               4      2             0
# 4             5            2               4      2             4
# ...         ...          ...             ...    ...           ...
# 300148        5            1               4      0             2
# 300149        5            1               0      0             5
# 300150        5            1               1      0             5
# 300151        5            1               1      0             2
# 300152        5            1               4      0             2
#
#         destination_city  class  price
# 0                      5      1   5953
# 1                      5      1   5953
# 2                      5      1   5956
# ...

# %%
model=RF.fit(x_train,y_train)
prediction=model.predict(x_test)

# %%
model.predict([[0,4,2,2,1,5,0]])
# Out:
# c:\Users\hisha\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([32011.39806373])

# %%
model.score(x_test,y_test)
# Out:
# 0.959008361847605

# %%
import pickle

# %%
# Flight_Price_Prediction=open('Flight_Price_Prediction.pkl','wb')
# Variable=pickle.dump(model,Flight_Price_Prediction)

# %%
FPP=open('FPP.pkl','wb')
VA=pickle.dump(model,FPP)

# %%
# print(sklearn.__version__)
